# %%
# This code computes all possible 

from pprint import pprint
from copy import deepcopy
import time

num_calls = 0
tried_solutions = set()
unique_solutions = set()

already_timed = set()
times = []

def package_cost(package, costs):
    return sum([package[i] * costs[i] for i in range(len(package))])

def get_remaining_funds(package, costs, max_budget):
    return max_budget - package_cost(package, costs)
    
def get_purchase_options(num_servers, costs, starting_funds, remaining_funds):
    global unique_solutions
    global tried_solutions
    global num_calls
    num_calls += 1
    solutions_found = []
    
    # We can't afford any new servers, but we have not overspent.
    # This is a valid solution and should be kept
    if (all([cost>remaining_funds for cost in costs])) and (remaining_funds >= 0):
        solutions_found.append(num_servers)
        unique_solutions.add(tuple(num_servers))
        
        #used for timing purposes
        if num_servers[0] not in already_timed:
            already_timed.add(num_servers[0])
            current_time = time.time()
            #print("current_time: {}".format(current_time))
            time_delta = time.time() - start_time - sum(times)
            times.append(round(time_delta, 1))
            print("="*40)
            print("first digit {} took {} seconds".format(num_servers[0],
                                                          round(time_delta, 1)))
            print("Solutions found so far: {}".format(len(unique_solutions)))
            
        #print("found solution: {}".format(num_servers))
        return solutions_found

    # We do not have enough money for this solution, so don't keep it.
    elif remaining_funds < 0:
        return solutions_found

    # There are some servers which we could still afford.
    else:
        for cost in costs:
            if cost <= remaining_funds:
                server_index = costs.index(cost)
                for i in range(1, (remaining_funds // cost)+1):
                    potential_servers = deepcopy(num_servers)
                    potential_servers[server_index] += i
                    potential_remaining_funds = get_remaining_funds(potential_servers, costs, starting_funds)

                    if tuple(potential_servers) not in tried_solutions:
                        tried_solutions.add(tuple(potential_servers))
                        solutions_found.extend(get_purchase_options(potential_servers, costs, starting_funds, potential_remaining_funds))

    #return only unique solutions
    unique_list = []
    for solution in solutions_found:
        if solution not in unique_list:
            unique_list.append(solution)
    return unique_list

# compute_nodes are a list of tuples.  
# The first element in tuple is a string representing the server's name.
# The second element in tuple is the price in dollars that server costs.
# The naming convention developed to keep track of servers was as follows:
# server model, processor type, Gb of memory, and number of GPUs, each separated by an underscore.
# Use whatever naming convention you find convenient.
compute_nodes = [('ComputeNode1', 6960),
                  ('ComputeNode2', 8178),
                  ('ComputeNode3', 8298),
                  ('ComputeNode4', 9516)]
                 
high_memory_nodes = [('BigMemNode1', 11112),
                     ('BigMemNode2', 12450)]
                 
gpu_nodes = [('GPUNode4', 14730),
             ('GPUNode8', 23480),
             ('GPUNode12', 39360),
             ("GPUNode1", 29150),
             ("GPUNode5", 35350),
             ("GPUNode9", 50225),
             ("GPUNode13", 85200),
             ("GPUNode2", 33620),
             ("GPUNode6", 39820),
             ("GPUNode10", 54695),
             ("GPUNode14", 89670),
             ("GPUNode3", 43950),
             ("GPUNode7", 50150),
             ("GPUNode11", 65025),
             ("GPUNode15", 100000)]

server_sets = []
for cn in compute_nodes:
    for hmn in high_memory_nodes:
        for gn in gpu_nodes:
            server_sets.append([cn, hmn, gn])

print("{} total packages found using one compute node, one big mem node, and one GPU node".format(len(server_sets)))

# Computing all of these takes quite some time
# We will pick only one for illustrative purposes
# This done in parallel using HPC resources
# You could easily wrap this in a for loop and iterate through all the possible server sets
# and combine them at the end.
server_costs = server_sets[0]
                    
print("="*40)
print("For package: {}".format(server_costs))
print("="*40)

costs = [cost for server_name, cost in server_costs]
# we have $1,000,000 to spend on servers
max_budget = 1000000

num_servers = [0 for i in range(len(costs))]

start_time = time.time()
# print("start time: {}".format(start_time))
solutions = get_purchase_options(num_servers, costs, max_budget, max_budget)
print("="*40)
print("{} solutions found for this server set".format(len(solutions)))
# pprint(solutions)

# In my case, I added an additional constrant that each server set must contain at least 1 GPU node. 
# I removed all possibilities that did not contain at least 1 GPU node.
# The resulting file with all possible combinations is found in ./data/server_combos_with_gpus.csv
# 126,688 possible combinations of the servers that I chose which we could afford, not afford to buy another,
# and contained at least one GPU node.
# Out:
# 120 total packages found using one compute node, one big mem node, and one GPU node
# ========================================
# For package: [('ComputeNode1', 6960), ('BigMemNode1', 11112), ('GPUNode4', 14730)]
# ========================================
# ========================================
# first digit 143 took 0.0 seconds
# Solutions found so far: 1
# ========================================
# first digit 142 took 0.0 seconds
# Solutions found so far: 2
# ========================================
# first digit 141 took 0.0 seconds
# Solutions found so far: 3
# ========================================
# first digit 140 took 0.0 seconds
# Solutions found so far: 4
# ========================================
# first digit 139 took 0.0 seconds
# Solutions found so far: 5
# ========================================
# first digit 138 took 0.0 seconds
# Solutions found so far: 7
# ========================================
# first digit 137 took 0.0 seconds
# Solutions found so far: 9
# ========================================
# first digit 136 took 0.0 seconds
# Solutions found so far: 12
# ========================================
# first digit 135 took 0.0 seconds
# Solutions found so far: 14
# ========================================
# first digit 134 took 0.0 seconds
# Solutions found so far: 18
# ========================================
# first digit 133 took 0.0 seconds
# Solutions found so far: 21
# ========================================
# first digit 132 took 0.0 seconds
# Solutions found so far: 25
# ========================================
# first digit 131 took 0.0 seconds
# Solutions found so far: 28
# ========================================
# first digit 130 took 0.0 seconds
# Solutions found so far: 31
# ========================================
# first digit 129 took 0.0 seconds
# Solutions found so far: 36
# ========================================
# first digit 128 took 0.0 seconds
# Solutions found so far: 41
# ========================================
# first digit 127 took 0.0 seconds
# Solutions found so far: 46
# ========================================
# first digit 126 took 0.0 seconds
# Solutions found so far: 52
# ========================================
# first digit 125 took 0.0 seconds
# Solutions found so far: 58
# ========================================
# first digit 124 took 0.0 seconds
# Solutions found so far: 64
# ========================================
# first digit 123 took 0.0 seconds
# Solutions found so far: 70
# ========================================
# first digit 122 took 0.0 seconds
# Solutions found so far: 75
# ========================================
# first digit 121 took 0.1 seconds
# Solutions found so far: 82
# ========================================
# first digit 120 took -0.0 seconds
# Solutions found so far: 89
# ========================================
# first digit 119 took -0.0 seconds
# Solutions found so far: 97
# ========================================
# first digit 118 took -0.0 seconds
# Solutions found so far: 105
# ========================================
# first digit 117 took -0.0 seconds
# Solutions found so far: 114
# ========================================
# first digit 116 took 0.0 seconds
# Solutions found so far: 122
# ========================================
# first digit 115 took 0.0 seconds
# Solutions found so far: 132
# ========================================
# first digit 114 took 0.0 seconds
# Solutions found so far: 139
# ========================================
# first digit 113 took 0.1 seconds
# Solutions found so far: 148
# ========================================
# first digit 112 took -0.0 seconds
# Solutions found so far: 156
# ========================================
# first digit 111 took -0.0 seconds
# Solutions found so far: 166
# ========================================
# first digit 110 took 0.0 seconds
# Solutions found so far: 177
# ========================================
# first digit 109 took 0.0 seconds
# Solutions found so far: 188
# ========================================
# first digit 108 took 0.1 seconds
# Solutions found so far: 199
# ========================================
# first digit 107 took -0.0 seconds
# Solutions found so far: 211
# ========================================
# first digit 106 took 0.0 seconds
# Solutions found so far: 221
# ========================================
# first digit 105 took 0.0 seconds
# Solutions found so far: 232
# ========================================
# first digit 104 took 0.1 seconds
# Solutions found so far: 243
# ========================================
# first digit 103 took 0.0 seconds
# Solutions found so far: 254
# ========================================
# first digit 102 took 0.0 seconds
# Solutions found so far: 268
# ========================================
# first digit 101 took 0.1 seconds
# Solutions found so far: 281
# ========================================
# first digit 100 took 0.0 seconds
# Solutions found so far: 295
# ========================================
# first digit 99 took 0.1 seconds
# Solutions found so far: 309
# ========================================
# first digit 98 took 0.0 seconds
# Solutions found so far: 323
# ========================================
# first digit 97 took 0.1 seconds
# Solutions found so far: 336
# ========================================
# first digit 96 took 0.0 seconds
# Solutions found so far: 350
# ========================================
# first digit 95 took 0.1 seconds
# Solutions found so far: 363
# ========================================
# first digit 94 took 0.1 seconds
# Solutions found so far: 378
# ========================================
# first digit 93 took 0.0 seconds
# Solutions found so far: 393
# ========================================
# first digit 92 took 0.1 seconds
# Solutions found so far: 409
# ========================================
# first digit 91 took 0.1 seconds
# Solutions found so far: 426
# ========================================
# first digit 90 took 0.1 seconds
# Solutions found so far: 442
# ========================================
# first digit 89 took 0.1 seconds
# Solutions found so far: 458
# ========================================
# first digit 88 took 0.1 seconds
# Solutions found so far: 474
# ========================================
# first digit 87 took 0.1 seconds
# Solutions found so far: 490
# ========================================
# first digit 86 took 0.1 seconds
# Solutions found so far: 507
# ========================================
# first digit 85 took 0.2 seconds
# Solutions found so far: 524
# ========================================
# first digit 84 took 0.1 seconds
# Solutions found so far: 542
# ========================================
# first digit 83 took 0.1 seconds
# Solutions found so far: 562
# ========================================
# first digit 82 took 0.1 seconds
# Solutions found so far: 581
# ========================================
# first digit 81 took 0.2 seconds
# Solutions found so far: 600
# ========================================
# first digit 80 took 0.1 seconds
# Solutions found so far: 618
# ========================================
# first digit 79 took 0.2 seconds
# Solutions found so far: 637
# ========================================
# first digit 78 took 0.2 seconds
# Solutions found so far: 655
# ========================================
# first digit 77 took 0.1 seconds
# Solutions found so far: 675
# ========================================
# first digit 76 took 0.2 seconds
# Solutions found so far: 694
# ========================================
# first digit 75 took 0.2 seconds
# Solutions found so far: 716
# ========================================
# first digit 74 took 0.2 seconds
# Solutions found so far: 738
# ========================================
# first digit 73 took 0.2 seconds
# Solutions found so far: 759
# ========================================
# first digit 72 took 0.2 seconds
# Solutions found so far: 780
# ========================================
# first digit 71 took 0.2 seconds
# Solutions found so far: 801
# ========================================
# first digit 70 took 0.2 seconds
# Solutions found so far: 823
# ========================================
# first digit 69 took 0.3 seconds
# Solutions found so far: 845
# ========================================
# first digit 68 took 0.2 seconds
# Solutions found so far: 867
# ========================================
# first digit 67 took 0.2 seconds
# Solutions found so far: 890
# ========================================
# first digit 66 took 0.3 seconds
# Solutions found so far: 914
# ========================================
# first digit 65 took 0.2 seconds
# Solutions found so far: 938
# ========================================
# first digit 64 took 0.3 seconds
# Solutions found so far: 962
# ========================================
# first digit 63 took 0.3 seconds
# Solutions found so far: 984
# ========================================
# first digit 62 took 0.4 seconds
# Solutions found so far: 1009
# ========================================
# first digit 61 took 0.3 seconds
# Solutions found so far: 1033
# ========================================
# first digit 60 took 0.3 seconds
# Solutions found so far: 1058
# ========================================
# first digit 59 took 0.3 seconds
# Solutions found so far: 1083
# ========================================
# first digit 58 took 0.3 seconds
# Solutions found so far: 1109
# ========================================
# first digit 57 took 0.4 seconds
# Solutions found so far: 1135
# ========================================
# first digit 56 took 0.4 seconds
# Solutions found so far: 1161
# ========================================
# first digit 55 took 0.3 seconds
# Solutions found so far: 1187
# ========================================
# first digit 54 took 0.5 seconds
# Solutions found so far: 1214
# ========================================
# first digit 53 took 0.4 seconds
# Solutions found so far: 1241
# ========================================
# first digit 52 took 0.4 seconds
# Solutions found so far: 1268
# ========================================
# first digit 51 took 0.6 seconds
# Solutions found so far: 1296
# ========================================
# first digit 50 took 0.5 seconds
# Solutions found so far: 1324
# ========================================
# first digit 49 took 0.4 seconds
# Solutions found so far: 1352
# ========================================
# first digit 48 took 0.5 seconds
# Solutions found so far: 1379
# ========================================
# first digit 47 took 0.5 seconds
# Solutions found so far: 1408
# ========================================
# first digit 46 took 0.5 seconds
# Solutions found so far: 1437
# ========================================
# first digit 45 took 0.5 seconds
# Solutions found so far: 1467
# ========================================
# first digit 44 took 0.5 seconds
# Solutions found so far: 1496
# ========================================
# first digit 43 took 0.6 seconds
# Solutions found so far: 1527
# ========================================
# first digit 42 took 0.6 seconds
# Solutions found so far: 1557
# ========================================
# first digit 41 took 0.5 seconds
# Solutions found so far: 1588
# ========================================
# first digit 40 took 0.6 seconds
# Solutions found so far: 1618
# ========================================
# first digit 39 took 0.6 seconds
# Solutions found so far: 1648
# ========================================
# first digit 38 took 0.7 seconds
# Solutions found so far: 1680
# ========================================
# first digit 37 took 0.6 seconds
# Solutions found so far: 1712
# ========================================
# first digit 36 took 0.7 seconds
# Solutions found so far: 1744
# ========================================
# first digit 35 took 0.6 seconds
# Solutions found so far: 1777
# ========================================
# first digit 34 took 0.8 seconds
# Solutions found so far: 1810
# ========================================
# first digit 33 took 0.7 seconds
# Solutions found so far: 1842
# ========================================
# first digit 32 took 0.7 seconds
# Solutions found so far: 1875
# ========================================
# first digit 31 took 0.8 seconds
# Solutions found so far: 1907
# ========================================
# first digit 30 took 0.8 seconds
# Solutions found so far: 1941
# ========================================
# first digit 29 took 0.8 seconds
# Solutions found so far: 1975
# ========================================
# first digit 28 took 0.8 seconds
# Solutions found so far: 2010
# ========================================
# first digit 27 took 0.8 seconds
# Solutions found so far: 2045
# ========================================
# first digit 26 took 0.9 seconds
# Solutions found so far: 2081
# ========================================
# first digit 25 took 0.9 seconds
# Solutions found so far: 2116
# ========================================
# first digit 24 took 0.9 seconds
# Solutions found so far: 2153
# ========================================
# first digit 23 took 0.9 seconds
# Solutions found so far: 2187
# ========================================
# first digit 22 took 1.0 seconds
# Solutions found so far: 2223
# ========================================
# first digit 21 took 1.0 seconds
# Solutions found so far: 2258
# ========================================
# first digit 20 took 1.1 seconds
# Solutions found so far: 2295
# ========================================
# first digit 19 took 1.1 seconds
# Solutions found so far: 2333
# ========================================
# first digit 18 took 1.0 seconds
# Solutions found so far: 2370
# ========================================
# first digit 17 took 1.2 seconds
# Solutions found so far: 2408
# ========================================
# first digit 16 took 1.1 seconds
# Solutions found so far: 2447
# ========================================
# first digit 15 took 1.1 seconds
# Solutions found so far: 2484
# ========================================
# first digit 14 took 1.3 seconds
# Solutions found so far: 2522
# ========================================
# first digit 13 took 1.3 seconds
# Solutions found so far: 2560
# ========================================
# first digit 12 took 1.3 seconds
# Solutions found so far: 2598
# ========================================
# first digit 11 took 1.3 seconds
# Solutions found so far: 2639
# ========================================
# first digit 10 took 1.3 seconds
# Solutions found so far: 2679
# ========================================
# first digit 9 took 1.4 seconds
# Solutions found so far: 2720
# ========================================
# first digit 8 took 1.4 seconds
# Solutions found so far: 2761
# ========================================
# first digit 7 took 1.6 seconds
# Solutions found so far: 2802
# ========================================
# first digit 6 took 1.6 seconds
# Solutions found so far: 2842
# ========================================
# first digit 5 took 1.5 seconds
# Solutions found so far: 2883
# ========================================
# first digit 4 took 1.5 seconds
# Solutions found so far: 2922
# ========================================
# first digit 3 took 1.6 seconds
# Solutions found so far: 2963
# ========================================
# first digit 2 took 1.5 seconds
# Solutions found so far: 3006
# ========================================
# first digit 1 took 1.6 seconds
# Solutions found so far: 3049
# ========================================
# first digit 0 took 1.6 seconds
# Solutions found so far: 3093
# ========================================
# 3135 solutions found for this server set
