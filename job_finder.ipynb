# %%
# imports needed

import pyspark
from pyspark.sql import DataFrame
from pyspark.sql.types import *
from pyspark.sql.functions import date_format
from pyspark.sql.functions import col
from pyspark.sql.functions import rand
from pyspark.sql.functions import udf

from matplotlib import pyplot as plt
# %matplotlib inline

import datetime
import math
from collections import defaultdict

from functools import reduce
from pprint import pprint

# %%
#log_file = "/homes/scotthutch/beocat_slurm_raw.csv"
log_file = "/homes/scotthutch/beocat_2021_raw.csv"

job_schema = StructType([StructField("Account",StringType(),True),
                         StructField("AdminComment",StringType(),True),
                         StructField("AllocCPUS",IntegerType(),True),
                         StructField("AllocGRES",StringType(),True),
                         StructField("AllocNodes",IntegerType(),True),
                         StructField("AllocTRES",StringType(),True),
                         StructField("AssocID",IntegerType(),True),
                         StructField("AveCPU",StringType(),True),
                         StructField("AveCPUFreq",StringType(),True),
                         StructField("AveDiskRead",StringType(),True),
                         StructField("AveDiskWrite",StringType(),True),
                         StructField("AvePages",StringType(),True),
                         StructField("AveRSS",StringType(),True),
                         StructField("AveVMSize",StringType(),True),
                         StructField("BlockID",StringType(),True),
                         StructField("Cluster",StringType(),True),
                         StructField("Comment",StringType(),True),
                         StructField("ConsumedEnergy",StringType(),True),
                         StructField("ConsumedEnergyRaw",StringType(),True),
                         StructField("CPUTime",StringType(),True),
                         StructField("CPUTimeRAW",IntegerType(),True),
                         StructField("DerivedExitCode",StringType(),True),
                         StructField("Elapsed",StringType(),True),
                         StructField("ElapsedRaw",IntegerType(),True),
                         StructField("Eligible",TimestampType(),True),
                         StructField("End",TimestampType(),True),
                         StructField("ExitCode",StringType(),True),
                         StructField("GID",IntegerType(),True),
                         StructField("Group",StringType(),True),
                         StructField("JobID",StringType(),True),
                         StructField("JobIDRaw",StringType(),True),
                         StructField("JobName",StringType(),True),
                         StructField("Layout",StringType(),True),
                         StructField("MaxDiskRead",StringType(),True),
                         StructField("MaxDiskReadNode",StringType(),True),
                         StructField("MaxDiskReadTask",StringType(),True),
                         StructField("MaxDiskWrite",StringType(),True),
                         StructField("MaxDiskWriteNode",StringType(),True),
                         StructField("MaxDiskWriteTask",StringType(),True),
                         StructField("MaxPages",StringType(),True),
                         StructField("MaxPagesNode",StringType(),True),
                         StructField("MaxPagesTask",StringType(),True),
                         StructField("MaxRSS",StringType(),True),
                         StructField("MaxRSSNode",StringType(),True),
                         StructField("MaxRSSTask",StringType(),True),
                         StructField("MaxVMSize",StringType(),True),
                         StructField("MaxVMSizeNode",StringType(),True),
                         StructField("MaxVMSizeTask",StringType(),True),
                         StructField("McsLabel",StringType(),True),
                         StructField("MinCPU",StringType(),True),
                         StructField("MinCPUNode",StringType(),True),
                         StructField("MinCPUTask",StringType(),True),
                         StructField("NCPUS",IntegerType(),True),
                         StructField("NNodes",IntegerType(),True),
                         StructField("NodeList",StringType(),True),
                         StructField("NTasks",StringType(),True),
                         StructField("Priority",IntegerType(),True),
                         StructField("Partition",StringType(),True),
                         StructField("QOS",StringType(),True),
                         StructField("QOSRAW",IntegerType(),True),
                         StructField("ReqCPUFreq",StringType(),True),
                         StructField("ReqCPUFreqMin",StringType(),True),
                         StructField("ReqCPUFreqMax",StringType(),True),
                         StructField("ReqCPUFreqGov",StringType(),True),
                         StructField("ReqCPUS",IntegerType(),True),
                         StructField("ReqGRES",StringType(),True),
                         StructField("ReqMem",StringType(),True),
                         StructField("ReqNodes",IntegerType(),True),
                         StructField("ReqTRES",StringType(),True),
                         StructField("Reservation",StringType(),True),
                         StructField("ReservationId",StringType(),True),
                         StructField("Reserved",StringType(),True),
                         StructField("ResvCPU",StringType(),True),
                         StructField("ResvCPURAW",IntegerType(),True),
                         StructField("Start",TimestampType(),True),
                         StructField("State",StringType(),True),
                         StructField("Submit",TimestampType(),True),
                         StructField("Suspended",StringType(),True),
                         StructField("SystemCPU",StringType(),True),
                         StructField("SystemComment",StringType(),True),
                         StructField("Timelimit",StringType(),True),
                         StructField("TimelimitRaw",IntegerType(),True),
                         StructField("TotalCPU",StringType(),True),
                         StructField("TRESUsageInAve",StringType(),True),
                         StructField("TRESUsageInMax",StringType(),True),
                         StructField("TRESUsageInMaxNode",StringType(),True),
                         StructField("TRESUsageInMaxTask",StringType(),True),
                         StructField("TRESUsageInMin",StringType(),True),
                         StructField("TRESUsageInMinNode",StringType(),True),
                         StructField("TRESUsageInMinTask",StringType(),True),
                         StructField("TRESUsageInTot",StringType(),True),
                         StructField("TRESUsageOutAve",StringType(),True),
                         StructField("TRESUsageOutMax",StringType(),True),
                         StructField("TRESUsageOutMaxNode",StringType(),True),
                         StructField("TRESUsageOutMaxTask",StringType(),True),
                         StructField("TRESUsageOutMin",StringType(),True),
                         StructField("TRESUsageOutMinNode",StringType(),True),
                         StructField("TRESUsageOutMinTask",StringType(),True),
                         StructField("TRESUsageOutTot",StringType(),True),
                         StructField("UID",IntegerType(),True),
                         StructField("User",StringType(),True),
                         StructField("UserCPU",StringType(),True),
                         StructField("WCKey",StringType(),True),
                         StructField("WCKeyID",IntegerType(),True),
                         StructField("WorkDir",StringType(),True)])

all_jobs = spark.read.csv(log_file, sep="|", header=True, schema=job_schema)
base_jobs = all_jobs.filter(~(all_jobs.JobID.contains("_")) & ~(all_jobs.JobID.contains(".")))

print("Found {} jobs".format(base_jobs.count()))
base_jobs.head()
# Out:
# Found 645834 jobs
# Row(Account='beodefault', AdminComment=None, AllocCPUS=8, AllocGRES=None, AllocNodes=1, AllocTRES='billing=8,cpu=8,mem=8G,node=1', AssocID=363, AveCPU=None, AveCPUFreq=None, AveDiskRead=None, AveDiskWrite=None, AvePages=None, AveRSS=None, AveVMSize=None, BlockID=None, Cluster='beocat', Comment=None, ConsumedEnergy=None, ConsumedEnergyRaw=None, CPUTime='1802-13:07:04', CPUTimeRAW=155740024, DerivedExitCode='0:0', Elapsed='225-07:38:23', ElapsedRaw=19467503, Eligible=datetime.datetime(2020, 5, 26, 16, 7, 20), End=datetime.datetime(2021, 1, 6, 22, 46, 1), ExitCode='0:0', GID=2547, Group='gowri_users', JobID='9579230', JobIDRaw='9579230', JobName='Den_10_32Ehz_1200fs_with_field', Layout=None, MaxDiskRead=None, MaxDiskReadNode=None, MaxDiskReadTask=None, MaxDiskWrite=None, MaxDiskWriteNode=None, MaxDiskWriteTask=None, MaxPages=None, MaxPagesNode=None, MaxPagesTask=None, MaxRSS=None, MaxRSSNode=None, MaxRSSTask=None, MaxVMSize=None, MaxVMSizeNode=None, MaxVMSizeTask=None, McsLabel=None, MinCPU=None, MinCPUNode=None, MinCPUTask=None, NCPUS=8, NNodes=1, NodeList='hero41', NTasks=None, Priority=81727, Partition='ksu-gen-highmem.q', QOS='normal', QOSRAW=1, ReqCPUFreq='Unknown', ReqCPUFreqMin='Unknown', ReqCPUFreqMax='Unknown', ReqCPUFreqGov='Unknown', ReqCPUS=8, ReqGRES=None, ReqMem='8Gn', ReqNodes=1, ReqTRES='billing=8,cpu=8,mem=8G,node=1', Reservation=None, ReservationId=None, Reserved='00:00:18', ResvCPU='00:02:24', ResvCPURAW=144, Start=datetime.datetime(2020, 5, 26, 16, 7, 38), State='CANCELLED', Submit=datetime.datetime(2020, 5, 26, 16, 7, 20), Suspended='00:00:00', SystemCPU='00:00:00', SystemComment=None, Timelimit='1-00:00:00', TimelimitRaw=1440, TotalCPU='00:00:00', TRESUsageInAve=None, TRESUsageInMax=None, TRESUsageInMaxNode=None, TRESUsageInMaxTask=None, TRESUsageInMin=None, TRESUsageInMinNode=None, TRESUsageInMinTask=None, TRESUsageInTot=None, TRESUsageOutAve=None, TRESUsageOutMax=None, TRESUsageOutMaxNode=None, TRESUsageOutMaxTask=None, TRESUsageOutMin=None, TRESUsageOutMinNode=None, TRESUsageOutMinTask=None, TRESUsageOutTot=None, UID=2546, User='gowri', UserCPU='00:00:00', WCKey=None, WCKeyID=0, WorkDir='/homes/gowri/Gausssian_submit_scripts/gdv.j01p_sample_inputs/nuc-elec_dyn_density_print')

# %%
# From OSG log data, we know the number of jobs in each 30 miunte time window.
# Unfortunetly, the OSG job logs do not contain all information needed to simulate (namely the amount of memory each job used)
# Need to construct a job set from Beocat log data that looks like OSG jobs
# Target is 3% of jobs request a GPU, and the vast majority of those only request one GPU.

def unionAll(*dfs):
    return reduce(DataFrame.unionAll, dfs)

@udf
def get_gres(tres_string):
    if tres_string == None:
        return 0
    for element in tres_string.split(","):
        if "gpu" in element:
            return int(element.split("=")[1])
    return 0

@udf
def get_mem(tres_string):
    if tres_string == None:
        return
    for element in tres_string.split(","):
        if "mem" in element:
            mem_str = element.split("=")[1]
            if "G" in mem_str:
                return int(float(mem_str.strip("G"))) * 1000000
            elif "M" in mem_str:
                return int(float(mem_str.strip("M"))) * 1000
            elif "T" in mem_str:
                return int(float(mem_str.strip("T"))) * 1000000000
            else:
                raise Exception("What? {}".format(mem_str))


# number of OSG jobs in each half hour
jobs_per_half_hour =   [168283603,
                        28643797,
                        15714596,
                        10900766,
                        8188928,
                        6908098,
                        5401470,
                        4327811,
                        3760481,
                        3059451,
                        3384589,
                        2394489,
                        2141512,
                        1978759,
                        1803829,
                        1727789,
                        1666278,
                        1378629,
                        1307098,
                        1222586,
                        1195983,
                        1108240,
                        1053850,
                        1034004,
                        1060313,
                        982037,
                        905671,
                        909243,
                        841967,
                        867482,
                        794127,
                        697510,
                        706359,
                        659095,
                        652969,
                        620483,
                        578792,
                        538649,
                        537734,
                        527385,
                        576537,
                        497013,
                        492077,
                        502074,
                        504790,
                        525113,
                        481785,
                        491481]

total_jobs = sum(jobs_per_half_hour)
start = 0

required_jobs = 24250
print("Constructing dataset with roughly {} jobs.".format(required_jobs))

# Add some columns
base_jobs_cols_added = base_jobs.withColumn("ReqMem", get_mem(col("ReqTREs"))) \
                                .withColumn("ReqMem", col("ReqMem").cast("int")) \
                                .withColumn("ReqGPUs", get_gres(col("ReqTREs"))) \
                                .withColumn("ReqGPUs", col("ReqGPUs").cast("int"))

# Filter out jobs which request more than 8GB of memory which have no GPUs
# GPU jobs get added later
low_mem_jobs = base_jobs_cols_added.filter((col("ReqMem") <= 8000000) & (col("ReqGPUs") == 0))
print("Have {} jobs with less than 8GB of memory".format(low_mem_jobs.count()))

job_groups = []

for index, num_jobs in enumerate(jobs_per_half_hour):
    print("="*40)
    end = start + 0.5
    start_sec = start * 60 * 60
    end_sec = end * 60 * 60
    
    percent_jobs_in_window = round(num_jobs/total_jobs * 100, 2)
    
    jobs_needed = math.ceil(percent_jobs_in_window/100 * required_jobs)
    
    print("Jobs from {:4} to {:4} hours were {}% of OSG data.".format(start,
                                                                      end,
                                                                      percent_jobs_in_window))
    print("I need to find {} jobs in this window".format(jobs_needed))
        
    jobs_in_window = low_mem_jobs.filter((col("CPUTimeRAW") > start_sec) & (col("CPUTimeRAW") < end_sec))
    num_jobs_in_window = jobs_in_window.count()
    print("Found {} jobs with this duration".format(num_jobs_in_window))
    if num_jobs_in_window >= jobs_needed:
        chosen_jobs = jobs_in_window.orderBy(rand(seed=42)).limit(jobs_needed)
        print("Selected {} at random".format(chosen_jobs.count()))
        job_groups.append(chosen_jobs)
    else:
        print("Not enough jobs")

    start += 0.5
# Out:
# Constructing dataset with roughly 24250 jobs.
# Have 332585 jobs with less than 8GB of memory
# ========================================
# Jobs from    0 to  0.5 hours were 57.13% of OSG data.
# I need to find 13855 jobs in this window
# Found 154623 jobs with this duration
# Selected 13855 at random
# ========================================
# Jobs from  0.5 to  1.0 hours were 9.73% of OSG data.
# I need to find 2360 jobs in this window
# Found 8480 jobs with this duration
# Selected 2360 at random
# ========================================
# Jobs from  1.0 to  1.5 hours were 5.34% of OSG data.
# I need to find 1295 jobs in this window
# Found 81070 jobs with this duration
# Selected 1295 at random
# ========================================
# Jobs from  1.5 to  2.0 hours were 3.7% of OSG data.
# I need to find 898 jobs in this window
# Found 31366 jobs with this duration
# Selected 898 at random
# ========================================
# Jobs from  2.0 to  2.5 hours were 2.78% of OSG data.
# I need to find 675 jobs in this window
# Found 2104 jobs with this duration
# Selected 675 at random
# ========================================
# Jobs from  2.5 to  3.0 hours were 2.35% of OSG data.
# I need to find 570 jobs in this window
# Found 4869 jobs with this duration
# Selected 570 at random
# ========================================
# Jobs from  3.0 to  3.5 hours were 1.83% of OSG data.
# I need to find 444 jobs in this window
# Found 1028 jobs with this duration
# Selected 444 at random
# ========================================
# Jobs from  3.5 to  4.0 hours were 1.47% of OSG data.
# I need to find 357 jobs in this window
# Found 768 jobs with this duration
# Selected 357 at random
# ========================================
# Jobs from  4.0 to  4.5 hours were 1.28% of OSG data.
# I need to find 311 jobs in this window
# Found 764 jobs with this duration
# Selected 311 at random
# ========================================
# Jobs from  4.5 to  5.0 hours were 1.04% of OSG data.
# I need to find 253 jobs in this window
# Found 726 jobs with this duration
# Selected 253 at random
# ========================================
# Jobs from  5.0 to  5.5 hours were 1.15% of OSG data.
# I need to find 279 jobs in this window
# Found 790 jobs with this duration
# Selected 279 at random
# ========================================
# Jobs from  5.5 to  6.0 hours were 0.81% of OSG data.
# I need to find 197 jobs in this window
# Found 524 jobs with this duration
# Selected 197 at random
# ========================================
# Jobs from  6.0 to  6.5 hours were 0.73% of OSG data.
# I need to find 178 jobs in this window
# Found 531 jobs with this duration
# Selected 178 at random
# ========================================
# Jobs from  6.5 to  7.0 hours were 0.67% of OSG data.
# I need to find 163 jobs in this window
# Found 544 jobs with this duration
# Selected 163 at random
# ========================================
# Jobs from  7.0 to  7.5 hours were 0.61% of OSG data.
# I need to find 148 jobs in this window
# Found 497 jobs with this duration
# Selected 148 at random
# ========================================
# Jobs from  7.5 to  8.0 hours were 0.59% of OSG data.
# I need to find 144 jobs in this window
# Found 496 jobs with this duration
# Selected 144 at random
# ========================================
# Jobs from  8.0 to  8.5 hours were 0.57% of OSG data.
# I need to find 139 jobs in this window
# Found 455 jobs with this duration
# Selected 139 at random
# ========================================
# Jobs from  8.5 to  9.0 hours were 0.47% of OSG data.
# I need to find 114 jobs in this window
# Found 392 jobs with this duration
# Selected 114 at random
# ========================================
# Jobs from  9.0 to  9.5 hours were 0.44% of OSG data.
# I need to find 107 jobs in this window
# Found 220 jobs with this duration
# Selected 107 at random
# ========================================
# Jobs from  9.5 to 10.0 hours were 0.42% of OSG data.
# I need to find 102 jobs in this window
# Found 188 jobs with this duration
# Selected 102 at random
# ========================================
# Jobs from 10.0 to 10.5 hours were 0.41% of OSG data.
# I need to find 100 jobs in this window
# Found 202 jobs with this duration
# Selected 100 at random
# ========================================
# Jobs from 10.5 to 11.0 hours were 0.38% of OSG data.
# I need to find 93 jobs in this window
# Found 245 jobs with this duration
# Selected 93 at random
# ========================================
# Jobs from 11.0 to 11.5 hours were 0.36% of OSG data.
# I need to find 88 jobs in this window
# Found 160 jobs with this duration
# Selected 88 at random
# ========================================
# Jobs from 11.5 to 12.0 hours were 0.35% of OSG data.
# I need to find 85 jobs in this window
# Found 145 jobs with this duration
# Selected 85 at random
# ========================================
# Jobs from 12.0 to 12.5 hours were 0.36% of OSG data.
# I need to find 88 jobs in this window
# Found 165 jobs with this duration
# Selected 88 at random
# ========================================
# Jobs from 12.5 to 13.0 hours were 0.33% of OSG data.
# I need to find 81 jobs in this window
# Found 95 jobs with this duration
# Selected 81 at random
# ========================================
# Jobs from 13.0 to 13.5 hours were 0.31% of OSG data.
# I need to find 76 jobs in this window
# Found 119 jobs with this duration
# Selected 76 at random
# ========================================
# Jobs from 13.5 to 14.0 hours were 0.31% of OSG data.
# I need to find 76 jobs in this window
# Found 89 jobs with this duration
# Selected 76 at random
# ========================================
# Jobs from 14.0 to 14.5 hours were 0.29% of OSG data.
# I need to find 71 jobs in this window
# Found 86 jobs with this duration
# Selected 71 at random
# ========================================
# Jobs from 14.5 to 15.0 hours were 0.29% of OSG data.
# I need to find 71 jobs in this window
# Found 183 jobs with this duration
# Selected 71 at random
# ========================================
# Jobs from 15.0 to 15.5 hours were 0.27% of OSG data.
# I need to find 66 jobs in this window
# Found 303 jobs with this duration
# Selected 66 at random
# ========================================
# Jobs from 15.5 to 16.0 hours were 0.24% of OSG data.
# I need to find 59 jobs in this window
# Found 340 jobs with this duration
# Selected 59 at random
# ========================================
# Jobs from 16.0 to 16.5 hours were 0.24% of OSG data.
# I need to find 59 jobs in this window
# Found 437 jobs with this duration
# Selected 59 at random
# ========================================
# Jobs from 16.5 to 17.0 hours were 0.22% of OSG data.
# I need to find 54 jobs in this window
# Found 413 jobs with this duration
# Selected 54 at random
# ========================================
# Jobs from 17.0 to 17.5 hours were 0.22% of OSG data.
# I need to find 54 jobs in this window
# Found 337 jobs with this duration
# Selected 54 at random
# ========================================
# Jobs from 17.5 to 18.0 hours were 0.21% of OSG data.
# I need to find 51 jobs in this window
# Found 306 jobs with this duration
# Selected 51 at random
# ========================================
# Jobs from 18.0 to 18.5 hours were 0.2% of OSG data.
# I need to find 49 jobs in this window
# Found 395 jobs with this duration
# Selected 49 at random
# ========================================
# Jobs from 18.5 to 19.0 hours were 0.18% of OSG data.
# I need to find 44 jobs in this window
# Found 303 jobs with this duration
# Selected 44 at random
# ========================================
# Jobs from 19.0 to 19.5 hours were 0.18% of OSG data.
# I need to find 44 jobs in this window
# Found 303 jobs with this duration
# Selected 44 at random
# ========================================
# Jobs from 19.5 to 20.0 hours were 0.18% of OSG data.
# I need to find 44 jobs in this window
# Found 343 jobs with this duration
# Selected 44 at random
# ========================================
# Jobs from 20.0 to 20.5 hours were 0.2% of OSG data.
# I need to find 49 jobs in this window
# Found 356 jobs with this duration
# Selected 49 at random
# ========================================
# Jobs from 20.5 to 21.0 hours were 0.17% of OSG data.
# I need to find 42 jobs in this window
# Found 398 jobs with this duration
# Selected 42 at random
# ========================================
# Jobs from 21.0 to 21.5 hours were 0.17% of OSG data.
# I need to find 42 jobs in this window
# Found 371 jobs with this duration
# Selected 42 at random
# ========================================
# Jobs from 21.5 to 22.0 hours were 0.17% of OSG data.
# I need to find 42 jobs in this window
# Found 329 jobs with this duration
# Selected 42 at random
# ========================================
# Jobs from 22.0 to 22.5 hours were 0.17% of OSG data.
# I need to find 42 jobs in this window
# Found 266 jobs with this duration
# Selected 42 at random
# ========================================
# Jobs from 22.5 to 23.0 hours were 0.18% of OSG data.
# I need to find 44 jobs in this window
# Found 277 jobs with this duration
# Selected 44 at random
# ========================================
# Jobs from 23.0 to 23.5 hours were 0.16% of OSG data.
# I need to find 39 jobs in this window
# Found 221 jobs with this duration
# Selected 39 at random
# ========================================
# Jobs from 23.5 to 24.0 hours were 0.17% of OSG data.
# I need to find 42 jobs in this window
# Found 222 jobs with this duration
# Selected 42 at random

# %%
# Need to make the GPUs requested look like OSG GPU jobs
num_gpus = [1,2,3,4]
gpu_targets = [725,10,2,10]

gpu_jobs = base_jobs_cols_added.filter((col("ReqMem") <= 8000000) & (col("ReqGPUs") > 0))

for index, num_gpu_jobs in enumerate(gpu_targets):
    print("="*40)
    print("Looking for {} jobs requesting {} GPU".format(num_gpu_jobs, num_gpus[index]))
    filtered_gpu_jobs = gpu_jobs.filter(col("ReqGPUs") == num_gpus[index])
    num_filtered_gpu_jobs = filtered_gpu_jobs.count()
    print("Found {} jobs requesting {} GPU".format(num_filtered_gpu_jobs, num_gpus[index]))
    
    if num_filtered_gpu_jobs >= num_gpu_jobs:
        chosen_jobs = filtered_gpu_jobs.orderBy(rand(seed=42)).limit(num_gpu_jobs)
        print("Selected {} at random".format(chosen_jobs.count()))
        job_groups.append(chosen_jobs)
    else:
        print("Not enough jobs")
# Out:
# ========================================
# Looking for 725 jobs requesting 1 GPU
# Found 11870 jobs requesting 1 GPU
# Selected 725 at random
# ========================================
# Looking for 10 jobs requesting 2 GPU
# Found 3756 jobs requesting 2 GPU
# Selected 10 at random
# ========================================
# Looking for 2 jobs requesting 3 GPU
# Found 2 jobs requesting 3 GPU
# Selected 2 at random
# ========================================
# Looking for 10 jobs requesting 4 GPU
# Found 45 jobs requesting 4 GPU
# Selected 10 at random

# %%
job_set = unionAll(*job_groups)
print("{} jobs found".format(job_set.count()))
# Out:
# 25031 jobs found

# %%
job_set.groupBy("ReqGPUs").count().sort("ReqGPUs").show()
# Out:
# +-------+-----+
# |ReqGPUs|count|
# +-------+-----+
# |      0|24284|
# |      1|  725|
# |      2|   10|
# |      3|    2|
# |      4|   10|
# +-------+-----+

# %%
# Need to shuffle these jobs to mix up their order.
job_set = job_set.orderBy(rand(seed=42))

# %%
job_set.head()
# Out:
# Row(Account='beodefault', AdminComment=None, AllocCPUS=4, AllocGRES=None, AllocNodes=1, AllocTRES='billing=4,cpu=4,mem=8000M,node=1', AssocID=2553, AveCPU=None, AveCPUFreq=None, AveDiskRead=None, AveDiskWrite=None, AvePages=None, AveRSS=None, AveVMSize=None, BlockID=None, Cluster='beocat', Comment=None, ConsumedEnergy='0', ConsumedEnergyRaw='0', CPUTime='01:23:04', CPUTimeRAW=4984, DerivedExitCode='0:0', Elapsed='00:20:46', ElapsedRaw=1246, Eligible=datetime.datetime(2021, 2, 19, 17, 38, 50), End=datetime.datetime(2021, 2, 19, 17, 59, 36), ExitCode='1:0', GID=3838, Group='osgsubmit_users', JobID='276864', JobIDRaw='276864', JobName='bl_AOrhRb', Layout=None, MaxDiskRead=None, MaxDiskReadNode=None, MaxDiskReadTask=None, MaxDiskWrite=None, MaxDiskWriteNode=None, MaxDiskWriteTask=None, MaxPages=None, MaxPagesNode=None, MaxPagesTask=None, MaxRSS=None, MaxRSSNode=None, MaxRSSTask=None, MaxVMSize=None, MaxVMSizeNode=None, MaxVMSizeTask=None, McsLabel=None, MinCPU=None, MinCPUNode=None, MinCPUTask=None, NCPUS=4, NNodes=1, NodeList='hero49', NTasks=None, Priority=69654, Partition='osg.q', QOS='normal', QOSRAW=1, ReqCPUFreq='Unknown', ReqCPUFreqMin='Unknown', ReqCPUFreqMax='Unknown', ReqCPUFreqGov='Unknown', ReqCPUS=4, ReqGRES=None, ReqMem=8000000, ReqNodes=1, ReqTRES='billing=4,cpu=4,mem=8000M,node=1', Reservation=None, ReservationId=None, Reserved='00:00:00', ResvCPU='00:00:00', ResvCPURAW=0, Start=datetime.datetime(2021, 2, 19, 17, 38, 50), State='FAILED', Submit=datetime.datetime(2021, 2, 19, 17, 38, 50), Suspended='00:00:00', SystemCPU='00:12.490', SystemComment=None, Timelimit='1-00:00:00', TimelimitRaw=1440, TotalCPU='00:19.783', TRESUsageInAve=None, TRESUsageInMax=None, TRESUsageInMaxNode=None, TRESUsageInMaxTask=None, TRESUsageInMin=None, TRESUsageInMinNode=None, TRESUsageInMinTask=None, TRESUsageInTot=None, TRESUsageOutAve=None, TRESUsageOutMax=None, TRESUsageOutMaxNode=None, TRESUsageOutMaxTask=None, TRESUsageOutMin=None, TRESUsageOutMinNode=None, TRESUsageOutMinTask=None, TRESUsageOutTot=None, UID=3838, User='osgsubmit', UserCPU='00:07.293', WCKey=None, WCKeyID=0, WorkDir='/homes/osgsubmit/bosco/sandbox/6b06/6b06247b/slate-osg.beocat.ksu.edu_9619_slate-osg.beocat.ksu.edu_9103.0_1613777893', ReqGPUs=0)

# %%
# output a job set to a file for use later.
save_path = "job_set_25000"
job_set.write.parquet(save_path)
print("DataFrame saved to {} folder".format(save_path))
# Out:
# DataFrame saved to job_set_25000 folder

# %%
# Read a previously saved job set
job_set = spark.read.parquet("job_set_50000")
job_set.show()
# Out:
# +----------+------------+---------+---------+----------+--------------------+-------+------+----------+-----------+------------+--------+------+---------+-------+-------+-------+--------------+-----------------+-----------+----------+---------------+----------+----------+-------------------+-------------------+--------+----+--------------------+-------+--------+--------------------+------+-----------+---------------+---------------+------------+----------------+----------------+--------+------------+------------+------+----------+----------+---------+-------------+-------------+--------+------+----------+----------+-----+------+--------------------+------+--------+------------------+------+------+----------+-------------+-------------+-------------+-------+-------+-------+--------+--------------------+-----------+-------------+--------+----------+----------+-------------------+-------------+-------------------+---------+---------+-------------+-----------+------------+-----------+--------------+--------------+------------------+------------------+--------------+------------------+------------------+--------------+---------------+---------------+-------------------+-------------------+---------------+-------------------+-------------------+---------------+----+-----------------+-----------+-----+-------+--------------------+-------+
# |   Account|AdminComment|AllocCPUS|AllocGRES|AllocNodes|           AllocTRES|AssocID|AveCPU|AveCPUFreq|AveDiskRead|AveDiskWrite|AvePages|AveRSS|AveVMSize|BlockID|Cluster|Comment|ConsumedEnergy|ConsumedEnergyRaw|    CPUTime|CPUTimeRAW|DerivedExitCode|   Elapsed|ElapsedRaw|           Eligible|                End|ExitCode| GID|               Group|  JobID|JobIDRaw|             JobName|Layout|MaxDiskRead|MaxDiskReadNode|MaxDiskReadTask|MaxDiskWrite|MaxDiskWriteNode|MaxDiskWriteTask|MaxPages|MaxPagesNode|MaxPagesTask|MaxRSS|MaxRSSNode|MaxRSSTask|MaxVMSize|MaxVMSizeNode|MaxVMSizeTask|McsLabel|MinCPU|MinCPUNode|MinCPUTask|NCPUS|NNodes|            NodeList|NTasks|Priority|         Partition|   QOS|QOSRAW|ReqCPUFreq|ReqCPUFreqMin|ReqCPUFreqMax|ReqCPUFreqGov|ReqCPUS|ReqGRES| ReqMem|ReqNodes|             ReqTRES|Reservation|ReservationId|Reserved|   ResvCPU|ResvCPURAW|              Start|        State|             Submit|Suspended|SystemCPU|SystemComment|  Timelimit|TimelimitRaw|   TotalCPU|TRESUsageInAve|TRESUsageInMax|TRESUsageInMaxNode|TRESUsageInMaxTask|TRESUsageInMin|TRESUsageInMinNode|TRESUsageInMinTask|TRESUsageInTot|TRESUsageOutAve|TRESUsageOutMax|TRESUsageOutMaxNode|TRESUsageOutMaxTask|TRESUsageOutMin|TRESUsageOutMinNode|TRESUsageOutMinTask|TRESUsageOutTot| UID|             User|    UserCPU|WCKey|WCKeyID|             WorkDir|ReqGPUs|
# +----------+------------+---------+---------+----------+--------------------+-------+------+----------+-----------+------------+--------+------+---------+-------+-------+-------+--------------+-----------------+-----------+----------+---------------+----------+----------+-------------------+-------------------+--------+----+--------------------+-------+--------+--------------------+------+-----------+---------------+---------------+------------+----------------+----------------+--------+------------+------------+------+----------+----------+---------+-------------+-------------+--------+------+----------+----------+-----+------+--------------------+------+--------+------------------+------+------+----------+-------------+-------------+-------------+-------+-------+-------+--------+--------------------+-----------+-------------+--------+----------+----------+-------------------+-------------+-------------------+---------+---------+-------------+-----------+------------+-----------+--------------+--------------+------------------+------------------+--------------+------------------+------------------+--------------+---------------+---------------+-------------------+-------------------+---------------+-------------------+-------------------+---------------+----+-----------------+-----------+-----+-------+--------------------+-------+
# |beodefault|        null|        8|     null|         1|billing=8,cpu=8,g...|    280|  null|      null|       null|        null|    null|  null|     null|   null| beocat|   null|             0|                0|34-03:35:28|   2950528|            0:0|4-06:26:56|    368816|2021-09-17 19:26:24|2021-09-22 01:53:24|     1:0|2476|        ploetz_users|1198632| 1198632|             .2Mntl9|  null|       null|           null|           null|        null|            null|            null|    null|        null|        null|  null|      null|      null|     null|         null|         null|    null|  null|      null|      null|    8|     1|            wizard04|  null|   49160|    ksu-chem-mri.q|normal|     1|   Unknown|      Unknown|      Unknown|      Unknown|      8|   null|8000000|       1|billing=8,cpu=8,g...|       null|         null|00:00:04|  00:00:32|        32|2021-09-17 19:26:28|       FAILED|2021-09-17 19:26:24| 00:00:00| 01:52:36|         null|28-00:00:00|       40320|32-02:57:09|          null|          null|              null|              null|          null|              null|              null|          null|           null|           null|               null|               null|           null|               null|               null|           null|2475|           ploetz|32-01:04:32| null|      0|/bulk/ploetz/smye...|      1|
# |beodefault|        null|        4|     null|         1|billing=4,cpu=4,m...|   2553|  null|      null|       null|        null|    null|  null|     null|   null| beocat|   null|             0|                0|   00:00:08|         8|            0:0|  00:00:02|         2|2021-03-11 18:37:29|2021-03-11 18:37:43|   127:0|3838|     osgsubmit_users| 372497|  372497|           bl_eiyCNT|  null|       null|           null|           null|        null|            null|            null|    null|        null|        null|  null|      null|      null|     null|         null|         null|    null|  null|      null|      null|    4|     1|             mole048|  null|   84590|             osg.q|normal|     1|   Unknown|      Unknown|      Unknown|      Unknown|      4|   null|8000000|       1|billing=4,cpu=4,m...|       null|         null|00:00:12|  00:00:48|        48|2021-03-11 18:37:41|       FAILED|2021-03-11 18:37:29| 00:00:00|00:00.039|         null| 1-00:00:00|        1440|  00:00.065|          null|          null|              null|              null|          null|              null|              null|          null|           null|           null|               null|               null|           null|               null|               null|           null|3838|        osgsubmit|  00:00.025| null|      0|/homes/osgsubmit/...|      0|
# |beodefault|        null|       10|     null|         1|billing=10,cpu=10...|   2151|  null|      null|       null|        null|    null|  null|     null|   null| beocat|   null|             0|                0|   00:00:30|        30|            0:0|  00:00:03|         3|2021-09-06 14:23:58|2021-09-06 14:24:02|    11:0|3438|   bayless1998_users|1137617| 1137617|    openmp_sbatch.sh|  null|       null|           null|           null|        null|            null|            null|    null|        null|        null|  null|      null|      null|     null|         null|         null|    null|  null|      null|      null|   10|     1|               elf11|  null|  855662|           batch.q|normal|     1|   Unknown|      Unknown|      Unknown|      Unknown|     10|   null|1000000|       1|billing=10,cpu=10...|       null|         null|00:00:01|  00:00:10|        10|2021-09-06 14:23:59|       FAILED|2021-09-06 14:23:58| 00:00:00|00:00.148|         null|   01:00:00|          60|  00:01.258|          null|          null|              null|              null|          null|              null|              null|          null|           null|           null|               null|               null|           null|               null|               null|           null|3438|      bayless1998|  00:01.109| null|      0|  /homes/bayless1998|      0|
# |beodefault|        null|        4|     null|         1|billing=4,cpu=4,m...|   2713|  null|      null|       null|        null|    null|  null|     null|   null| beocat|   null|             0|                0|   00:01:32|        92|            0:0|  00:00:23|        23|2021-08-10 14:43:36|2021-08-10 14:44:01|   0:125|4000|matthewculbert343...| 957672|  957672|                ASPP|  null|       null|           null|           null|        null|            null|            null|    null|        null|        null|  null|      null|      null|     null|         null|         null|    null|  null|      null|      null|    4|     1|           warlock08|  null|  584973|        killable.q|normal|     1|   Unknown|      Unknown|      Unknown|      Unknown|      4|   null|8000000|       1|billing=4,cpu=4,m...|       null|         null|00:00:02|  00:00:08|         8|2021-08-10 14:43:38|OUT_OF_MEMORY|2021-08-10 14:43:36| 00:00:00|00:03.403|         null| 2-00:00:00|        2880|  00:03.964|          null|          null|              null|              null|          null|              null|              null|          null|           null|           null|               null|               null|           null|               null|               null|           null|4000|matthewculbert343|  00:00.561| null|      0|/homes/matthewcul...|      0|
# |beodefault|        null|        4|     null|         1|billing=4,cpu=4,m...|    213|  null|      null|       null|        null|    null|  null|     null|   null| beocat|   null|             0|                0|   04:01:52|     14512|            0:0|  01:00:28|      3628|2021-08-03 09:56:54|2021-08-03 10:57:28|     0:0|2647|      lukesteg_users| 941718|  941718|                ASPP|  null|       null|           null|           null|        null|            null|            null|    null|        null|        null|  null|      null|      null|     null|         null|         null|    null|  null|      null|      null|    4|     1|             dwarf15|  null|  291183|        killable.q|normal|     1|   Unknown|      Unknown|      Unknown|      Unknown|      4|   null|4000000|       1|billing=4,cpu=4,m...|       null|         null|00:00:06|  00:00:24|        24|2021-08-03 09:57:00|    COMPLETED|2021-08-03 09:56:54| 00:00:00|00:00.843|         null|   08:00:00|         480|   04:00:40|          null|          null|              null|              null|          null|              null|              null|          null|           null|           null|               null|               null|           null|               null|               null|           null|2646|         lukesteg|   04:00:39| null|      0|/homes/lukesteg/S...|      0|
# |beodefault|        null|        4|     null|         1|billing=4,cpu=4,m...|   2553|  null|      null|       null|        null|    null|  null|     null|   null| beocat|   null|             0|                0|   01:23:56|      5036|            0:0|  00:20:59|      1259|2021-03-21 11:18:59|2021-03-21 11:39:58|     1:0|3838|     osgsubmit_users| 434317|  434317|           bl_4ihpQ8|  null|       null|           null|           null|        null|            null|            null|    null|        null|        null|  null|      null|      null|     null|         null|         null|    null|  null|      null|      null|    4|     1|             mole091|  null|  101600|             osg.q|normal|     1|   Unknown|      Unknown|      Unknown|      Unknown|      4|   null|8000000|       1|billing=4,cpu=4,m...|       null|         null|00:00:00|  00:00:00|         0|2021-03-21 11:18:59|       FAILED|2021-03-21 11:18:59| 00:00:00|00:12.368|         null| 1-00:00:00|        1440|  00:18.425|          null|          null|              null|              null|          null|              null|              null|          null|           null|           null|               null|               null|           null|               null|               null|           null|3838|        osgsubmit|  00:06.056| null|      0|/homes/osgsubmit/...|      0|
# |beodefault|        null|        1|     null|         1|billing=1,cpu=1,m...|    210|  null|      null|       null|        null|    null|  null|     null|   null| beocat|   null|             0|                0|   00:01:27|        87|            0:0|  00:01:27|        87|2021-06-11 00:48:21|2021-06-11 00:50:12|     0:0|2048|       pierre1_users| 729516|  729516|align_script_3611.sh|  null|       null|           null|           null|        null|            null|            null|    null|        null|        null|  null|      null|      null|     null|         null|         null|    null|  null|      null|      null|    1|     1|             mole017|  null|  303748|        killable.q|normal|     1|   Unknown|      Unknown|      Unknown|      Unknown|      1|   null|5000000|       1|billing=1,cpu=1,m...|       null|         null|00:00:24|  00:00:24|        24|2021-06-11 00:48:45|    COMPLETED|2021-06-11 00:48:21| 00:00:00|00:00.107|         null|   02:00:00|         120|  01:25.005|          null|          null|              null|              null|          null|              null|              null|          null|           null|           null|               null|               null|           null|               null|               null|           null|2047|          pierre1|  01:24.897| null|      0|/homes/pierre1/bi...|      0|
# |beodefault|        null|       32|     null|         8|billing=32,cpu=32...|   2605|  null|      null|       null|        null|    null|  null|     null|   null| beocat|   null|             0|                0|   00:37:20|      2240|            0:0|  00:01:10|        70|2021-05-05 19:35:10|2021-05-05 19:37:37|     0:0|3891|    mcgowans06_users| 606130|  606130|           openmp.sh|  null|       null|           null|           null|        null|            null|            null|    null|        null|        null|  null|      null|      null|     null|         null|         null|    null|  null|      null|      null|   32|     8|elf[06,10,12-14,1...|  null|  516928|           batch.q|normal|     1|   Unknown|      Unknown|      Unknown|      Unknown|     32|   null|8000000|       8|billing=32,cpu=32...|       null|         null|00:01:17|  00:41:04|      2464|2021-05-05 19:36:27|    COMPLETED|2021-05-05 19:35:10| 00:00:00|00:00.456|         null|   01:00:00|          60|  01:11.706|          null|          null|              null|              null|          null|              null|              null|          null|           null|           null|               null|               null|           null|               null|               null|           null|3891|       mcgowans06|  01:11.250| null|      0|/homes/mcgowans06...|      0|
# |beodefault|        null|        1|     null|         1|billing=1,cpu=1,m...|    210|  null|      null|       null|        null|    null|  null|     null|   null| beocat|   null|             0|                0|   00:00:13|        13|            0:0|  00:00:13|        13|2021-06-11 00:09:28|2021-06-11 00:09:53|     0:0|2048|       pierre1_users| 725814|  725814| align_script_882.sh|  null|       null|           null|           null|        null|            null|            null|    null|        null|        null|  null|      null|      null|     null|         null|         null|    null|  null|      null|      null|    1|     1|             mole001|  null|  303748|        killable.q|normal|     1|   Unknown|      Unknown|      Unknown|      Unknown|      1|   null|5000000|       1|billing=1,cpu=1,m...|       null|         null|00:00:12|  00:00:12|        12|2021-06-11 00:09:40|    COMPLETED|2021-06-11 00:09:28| 00:00:00|00:00.092|         null|   02:00:00|         120|  00:11.177|          null|          null|              null|              null|          null|              null|              null|          null|           null|           null|               null|               null|           null|               null|               null|           null|2047|          pierre1|  00:11.085| null|      0|/homes/pierre1/bi...|      0|
# |beodefault|        null|        4|     null|         1|billing=4,cpu=4,m...|   2553|  null|      null|       null|        null|    null|  null|     null|   null| beocat|   null|             0|                0|   01:21:04|      4864|            0:0|  00:20:16|      1216|2021-02-12 21:32:51|2021-02-12 21:53:07|     1:0|3838|     osgsubmit_users| 210826|  210826|           bl_KtXhNy|  null|       null|           null|           null|        null|            null|            null|    null|        null|        null|  null|      null|      null|     null|         null|         null|    null|  null|      null|      null|    4|     1|               elf07|  null|  125926|           batch.q|normal|     1|   Unknown|      Unknown|      Unknown|      Unknown|      4|   null|8000000|       1|billing=4,cpu=4,m...|       null|         null|00:00:00|  00:00:00|         0|2021-02-12 21:32:51|       FAILED|2021-02-12 21:32:51| 00:00:00|00:03.738|         null| 1-00:00:00|        1440|  00:06.731|          null|          null|              null|              null|          null|              null|              null|          null|           null|           null|               null|               null|           null|               null|               null|           null|3838|        osgsubmit|  00:02.993| null|      0|/homes/osgsubmit/...|      0|
# |beodefault|        null|        4|     null|         1|billing=4,cpu=4,m...|   2553|  null|      null|       null|        null|    null|  null|     null|   null| beocat|   null|             0|                0|   00:00:12|        12|            0:0|  00:00:03|         3|2021-03-13 02:26:06|2021-03-13 02:26:25|   127:0|3838|     osgsubmit_users| 380644|  380644|           bl_pJarvf|  null|       null|           null|           null|        null|            null|            null|    null|        null|        null|  null|      null|      null|     null|         null|         null|    null|  null|      null|      null|    4|     1|               elf08|  null|   93736|             osg.q|normal|     1|   Unknown|      Unknown|      Unknown|      Unknown|      4|   null|8000000|       1|billing=4,cpu=4,m...|       null|         null|00:00:16|  00:01:04|        64|2021-03-13 02:26:22|       FAILED|2021-03-13 02:26:06| 00:00:00|00:00.053|         null| 1-00:00:00|        1440|  00:00.073|          null|          null|              null|              null|          null|              null|              null|          null|           null|           null|               null|               null|           null|               null|               null|           null|3838|        osgsubmit|  00:00.020| null|      0|/homes/osgsubmit/...|      0|
# |beodefault|        null|        4|     null|         1|billing=4,cpu=4,m...|   2553|  null|      null|       null|        null|    null|  null|     null|   null| beocat|   null|             0|                0|   01:41:28|      6088|            0:0|  00:25:22|      1522|2021-03-23 06:37:16|2021-03-23 07:02:44|     0:0|3838|     osgsubmit_users| 445571|  445571|           bl_M39vGa|  null|       null|           null|           null|        null|            null|            null|    null|        null|        null|  null|      null|      null|     null|         null|         null|    null|  null|      null|      null|    4|     1|             mole082|  null|   67428|             osg.q|normal|     1|   Unknown|      Unknown|      Unknown|      Unknown|      4|   null|8000000|       1|billing=4,cpu=4,m...|       null|         null|00:00:06|  00:00:24|        24|2021-03-23 06:37:22|    COMPLETED|2021-03-23 06:37:16| 00:00:00|00:21.890|         null| 1-00:00:00|        1440|  00:52.269|          null|          null|              null|              null|          null|              null|              null|          null|           null|           null|               null|               null|           null|               null|               null|           null|3838|        osgsubmit|  00:30.378| null|      0|/homes/osgsubmit/...|      0|
# |beodefault|        null|        4|     null|         1|billing=4,cpu=4,m...|   2553|  null|      null|       null|        null|    null|  null|     null|   null| beocat|   null|             0|                0|   02:43:40|      9820|            0:0|  00:40:55|      2455|2021-02-13 20:11:51|2021-02-13 20:52:46|     1:0|3838|     osgsubmit_users| 217264|  217264|           bl_ikh8xM|  null|       null|           null|           null|        null|            null|            null|    null|        null|        null|  null|      null|      null|     null|         null|         null|    null|  null|      null|      null|    4|     1|               elf12|  null|  105093|           batch.q|normal|     1|   Unknown|      Unknown|      Unknown|      Unknown|      4|   null|8000000|       1|billing=4,cpu=4,m...|       null|         null|00:00:00|  00:00:00|         0|2021-02-13 20:11:51|       FAILED|2021-02-13 20:11:51| 00:00:00|00:03.674|         null| 1-00:00:00|        1440|  00:06.623|          null|          null|              null|              null|          null|              null|              null|          null|           null|           null|               null|               null|           null|               null|               null|           null|3838|        osgsubmit|  00:02.949| null|      0|/homes/osgsubmit/...|      0|
# |beodefault|        null|        1|     null|         1|billing=1,cpu=1,m...|    608|  null|      null|       null|        null|    null|  null|     null|   null| beocat|   null|             0|                0|   00:59:03|      3543|            0:0|  00:59:03|      3543|2021-05-24 21:38:06|2021-05-24 22:37:27|     0:0|2473|         feihe_users| 652665|  652665|         run_2824.sh|  null|       null|           null|           null|        null|            null|            null|    null|        null|        null|  null|      null|      null|     null|         null|         null|    null|  null|      null|      null|    1|     1|              hero14|  null|   42376|        killable.q|normal|     1|   Unknown|      Unknown|      Unknown|      Unknown|      1|   null|4000000|       1|billing=1,cpu=1,m...|       null|         null|00:00:18|  00:00:18|        18|2021-05-24 21:38:24|    COMPLETED|2021-05-24 21:38:06| 00:00:00|00:13.913|         null| 3-11:02:00|        4982|  58:53.916|          null|          null|              null|              null|          null|              null|              null|          null|           null|           null|               null|               null|           null|               null|               null|           null|2472|            feihe|  58:40.002| null|      0|/homes/feihe/proj...|      0|
# |beodefault|        null|        4|     null|         1|billing=4,cpu=4,m...|   2726|  null|      null|       null|        null|    null|  null|     null|   null| beocat|   null|             0|                0|   00:00:04|         4|            0:0|  00:00:01|         1|2021-08-29 13:47:43|2021-08-29 13:47:45|     0:0|4013|      bwbednar_users|1081389| 1081389|HW0_Script_Num_2....|  null|       null|           null|           null|        null|            null|            null|    null|        null|        null|  null|      null|      null|     null|         null|         null|    null|  null|      null|      null|    4|     1|               elf45|  null| 1381928|           batch.q|normal|     1|   Unknown|      Unknown|      Unknown|      Unknown|      4|   null|2000000|       1|billing=4,cpu=4,m...|       null|         null|00:00:01|  00:00:04|         4|2021-08-29 13:47:44|    COMPLETED|2021-08-29 13:47:43| 00:00:00|00:00.005|         null|   00:10:00|          10|  00:00.005|          null|          null|              null|              null|          null|              null|              null|          null|           null|           null|               null|               null|           null|               null|               null|           null|4013|         bwbednar|   00:00:00| null|      0|     /homes/bwbednar|      0|
# |beodefault|        null|        4|     null|         1|billing=4,cpu=4,m...|   2553|  null|      null|       null|        null|    null|  null|     null|   null| beocat|   null|             0|                0|   00:49:52|      2992|            0:0|  00:12:28|       748|2021-05-04 09:52:46|2021-05-04 13:30:16|     0:0|3838|     osgsubmit_users| 586701|  586701|           bl_tlRnXP|  null|       null|           null|           null|        null|            null|            null|    null|        null|        null|  null|      null|      null|     null|         null|         null|    null|  null|      null|      null|    4|     1|             mole049|  null|   23413|             osg.q|normal|     1|   Unknown|      Unknown|      Unknown|      Unknown|      4|   null|8000000|       1|billing=4,cpu=4,m...|       null|         null|03:25:02|  13:40:08|     49208|2021-05-04 13:17:48|    COMPLETED|2021-05-04 09:50:45| 00:00:00|00:25.026|         null| 1-00:00:00|        1440|  00:51.135|          null|          null|              null|              null|          null|              null|              null|          null|           null|           null|               null|               null|           null|               null|               null|           null|3838|        osgsubmit|  00:26.108| null|      0|/homes/osgsubmit/...|      0|
# |beodefault|        null|        4|     null|         1|billing=4,cpu=4,m...|   2553|  null|      null|       null|        null|    null|  null|     null|   null| beocat|   null|             0|                0|   02:14:36|      8076|            0:0|  00:33:39|      2019|2021-05-20 12:25:57|2021-05-21 11:59:26|     1:0|3838|     osgsubmit_users| 637584|  637584|           bl_3GNaTj|  null|       null|           null|           null|        null|            null|            null|    null|        null|        null|  null|      null|      null|     null|         null|         null|    null|  null|      null|      null|    4|     1|             mole016|  null|   13784|             osg.q|normal|     1|   Unknown|      Unknown|      Unknown|      Unknown|      4|   null|8000000|       1|billing=4,cpu=4,m...|       null|         null|22:59:50|3-19:59:20|    331160|2021-05-21 11:25:47|       FAILED|2021-05-20 12:25:57| 00:00:00|00:26.950|         null| 1-00:00:00|        1440|  00:43.406|          null|          null|              null|              null|          null|              null|              null|          null|           null|           null|               null|               null|           null|               null|               null|           null|3838|        osgsubmit|  00:16.456| null|      0|/homes/osgsubmit/...|      0|
# |beodefault|        null|        1|     null|         1|billing=1,cpu=1,m...|    213|  null|      null|       null|        null|    null|  null|     null|   null| beocat|   null|             0|                0|   00:00:40|        40|            0:0|  00:00:40|        40|2021-08-20 17:19:02|2021-08-20 17:19:43|     1:0|2647|      lukesteg_users|1047882| 1047882|      image-analysis|  null|       null|           null|           null|        null|            null|            null|    null|        null|        null|  null|      null|      null|     null|         null|         null|    null|  null|      null|      null|    1|     1|            wizard33|  null|  122002|ksu-mne-bahadori.q|normal|     1|   Unknown|      Unknown|      Unknown|      Unknown|      1|   null|8000000|       1|billing=1,cpu=1,m...|       null|         null|00:00:01|  00:00:01|         1|2021-08-20 17:19:03|       FAILED|2021-08-20 17:19:02| 00:00:00|00:01.140|         null|   01:00:00|          60|  00:30.442|          null|          null|              null|              null|          null|              null|              null|          null|           null|           null|               null|               null|           null|               null|               null|           null|2646|         lukesteg|  00:29.302| null|      0|/homes/lukesteg/S...|      0|
# |beodefault|        null|        4|     null|         1|billing=4,cpu=4,m...|   2725|  null|      null|       null|        null|    null|  null|     null|   null| beocat|   null|             0|                0|   00:00:04|         4|            0:0|  00:00:01|         1|2021-09-24 16:10:25|2021-09-24 16:10:26|   127:0|4012|       islater_users|1235145| 1235145|              run.sh|  null|       null|           null|           null|        null|            null|            null|    null|        null|        null|  null|      null|      null|     null|         null|         null|    null|  null|      null|      null|    4|     1|              hero22|  null|  649611|           batch.q|normal|     1|   Unknown|      Unknown|      Unknown|      Unknown|      4|   null|1000000|       1|billing=4,cpu=4,m...|       null|         null|00:00:00|  00:00:00|         0|2021-09-24 16:10:25|       FAILED|2021-09-24 16:10:25| 00:00:00|00:00.011|         null|   01:00:00|          60|  00:00.017|          null|          null|              null|              null|          null|              null|              null|          null|           null|           null|               null|               null|           null|               null|               null|           null|4012|          islater|  00:00.006| null|      0|/homes/islater/Co...|      0|
# |beodefault|        null|        8|     null|         1|billing=8,cpu=8,m...|   2635|  null|      null|       null|        null|    null|  null|     null|   null| beocat|   null|             0|                0|   00:03:12|       192|            0:0|  00:00:24|        24|2021-05-03 11:52:01|2021-05-03 11:52:51|   0:125|3921|          phyo_users| 579561|  579561|   pthread_sbatch.sh|  null|       null|           null|           null|        null|            null|            null|    null|        null|        null|  null|      null|      null|     null|         null|         null|    null|  null|      null|      null|    8|     1|               elf28|  null|  839943|           batch.q|normal|     1|   Unknown|      Unknown|      Unknown|      Unknown|      8|   null|1000000|       1|billing=8,cpu=8,m...|       null|         null|00:00:26|  00:03:28|       208|2021-05-03 11:52:27|OUT_OF_MEMORY|2021-05-03 11:52:01| 00:00:00|00:02.365|         null|   01:00:00|          60|  00:05.832|          null|          null|              null|              null|          null|              null|              null|          null|           null|           null|               null|               null|           null|               null|               null|           null|3921|             phyo|  00:03.466| null|      0|/homes/phyo/cis52...|      0|
# +----------+------------+---------+---------+----------+--------------------+-------+------+----------+-----------+------------+--------+------+---------+-------+-------+-------+--------------+-----------------+-----------+----------+---------------+----------+----------+-------------------+-------------------+--------+----+--------------------+-------+--------+--------------------+------+-----------+---------------+---------------+------------+----------------+----------------+--------+------------+------------+------+----------+----------+---------+-------------+-------------+--------+------+----------+----------+-----+------+--------------------+------+--------+------------------+------+------+----------+-------------+-------------+-------------+-------+-------+-------+--------+--------------------+-----------+-------------+--------+----------+----------+-------------------+-------------+-------------------+---------+---------+-------------+-----------+------------+-----------+--------------+--------------+------------------+------------------+--------------+------------------+------------------+--------------+---------------+---------------+-------------------+-------------------+---------------+-------------------+-------------------+---------------+----+-----------------+-----------+-----+-------+--------------------+-------+
# only showing top 20 rows

# %%
jobs = job_set.collect()

# %%
# Need to modify the submit dates to pack them into the same time period.
# Also generate new unique jobIDs for each job
job_id = 1000
start_date = datetime.datetime(year=2022,
                               month=1,
                               day=1,
                               hour=0,
                               minute=0,
                               second=0
                              )
time_shift = datetime.timedelta(seconds=3)
current_time = start_date

#build a trace file R script for R to run
R_string = "library(RSlurmSimTools)\n\ntrace <- list(\n"
for job in jobs:
    #print(job)
    job_id += 1
    current_time += time_shift
    
    R_string += " "*4 +"sim_job(\n"
    R_string += " "*8 + "job_id = " + str(job_id) + ",\n"
    R_string += " "*8 + "submit = \"" + str(current_time) + "\",\n"

    req_seconds = int(job.TimelimitRaw)
    req_minutes = math.ceil(req_seconds/60)
    R_string += " "*8 + "wclimit = " + str(req_minutes) + "L,\n"
    R_string += " "*8 + "duration = " + str(job.ElapsedRaw) + "L,\n"
    R_string += " "*8 + "tasks = " + str(job.ReqCPUS) + "L,\n"
    R_string += " "*8 + "tasks_per_node = " + str(job.ReqNodes) + "L,\n"
    R_string += " "*8 + "username = \"" + job.User + "\",\n"
    R_string += " "*8 + "qosname = \"" + job.QOS + "\",\n"
    R_string += " "*8 + "account = \"" + job.Account + "\",\n"
    R_string += " "*8 + "req_mem = " + str(job.ReqMem) + "L,\n"
    R_string += " "*8 + "req_mem_per_cpu = " + str(job.ReqMem) + "L,\n"
    
    if job.ReqGPUs != 0:
        R_string += " "*8 + "gres = \"gpu:{}".format(job.ReqGPUs) + "\",\n"
    R_string = R_string.strip(",\n") + "\n"
    #print("R_string here: {}".format(repr(R_string)))
    R_string += " "*4 + "),\n"

R_string = R_string.strip(",\n") + "\n)\n\ntrace <- do.call(rbind, lapply(trace,data.frame))\n\nwrite_trace(\"/slurm_sim_ws/sim/micro/baseline/input_files/test.trace\",trace)"

with open("trace.R", "w") as f_out:
    f_out.write(R_string)
print("R file written to trace.R")

#print(R_string)
# Out:
# R file written to trace.R

# %%
# Generate the sacctmgr_commands.txt and the users.sim file needed for this job set

#production
users_file_name = r"users.sim"
sacctmgr_file_name = r"sacctmgr_commands.txt"
#testing
#users_file_name = r"/homes/scotthutch/singularity_slurm/run_folders/etc/users.sim"
#sacctmgr_file_name = r"/homes/scotthutch/singularity_slurm/run_folders/input_files/sacctmgr_commands.txt"

accounts_with_users = defaultdict(set)

for job in jobs:
   accounts_with_users[job.Account].add(job.User)

users_file = open(users_file_name, "w")
sacctmgr_file = open(sacctmgr_file_name, "w")

#sacctmgr_file.write("modify QOS set normal Priority=0\n")
#sacctmgr_file.write("add QOS Name=supporters Priority=100\n")
#sacctmgr_file.write("add cluster Name=beocat Fairshare=1 QOS=normal,supporters\n")

for account, user_set in accounts_with_users.items():
    sacctmgr_file.write("add account name={} Fairshare=100\n".format(account))

    for user in user_set:
        sacctmgr_file.write("add user name={} DefaultAccount={} MaxSubmitJobs=10000\n".format(user, account))

sacctmgr_file.write("modify user set qoslevel=\"normal,supporters\"")

UID = 2001
users = set()

for user_set in accounts_with_users.values():
    users = users.union(user_set)

for user in users:
    users_file.write("{}:{}\n".format(user, UID))
    UID += 1

sacctmgr_file.write("\n")

users_file.close()
sacctmgr_file.close()

print("Users file created:  {}".format(users_file_name))
print("sacctmgr directives created: {}".format(sacctmgr_file_name))
# Out:
# Users file created:  users.sim
# sacctmgr directives created: sacctmgr_commands.txt
